# %%
import numpy as np
import pandas as pd
import hdbscan
from bertopic import BERTopic
import umap
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.cluster import OPTICS
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv('shops_public_products.csv')

# %%
df.head(3)
# Out:
#    product_no         brand                         category  \
# 0           1        Fifine                       Для стрима
# 1           2           NaN  Чехлы для плееров и аудиосистем
# 2           3  zKissfashion               Микрофонные стойки
#
#                                                 link  price  \
# 0  https://www.ozon.ru/product/mikrofon-igrovoy-d...   4990
# 1  https://www.ozon.ru/product/sumka-keys-dlya-hr...   2023
# 2  https://www.ozon.ru/product/stoyka-dlya-mikrof...    644
#
#                                          description  seller_id  \
# 0  Тип : Микрофон\nТехнология микрофона : Конденс...      81744
# 1  Тип : Чехол для портативной АС\nМатериал : Тек...     193106
# 2  Тип : Микрофонная стойка\nПартномер : 111\nЦве...     369734
#
#                                                 name  \
# 0  Микрофон игровой (для стриминга) Fifine AmpliG...
# 1  Сумка (кейс) для хранения портативной (блютуз)...
# 2  Стойка для микрофона/Держатель для микрофона/П...
#
#                                           image_link  \
# 0  https://cdn1.ozone.ru/s3/multimedia-v/61687660...
# 1  https://cdn1.ozone.ru/s3/multimedia-s/62246952...
# 2  https://cdn1.ozone.ru/s3/multimedia-s/62915439...
#
#                                            full_info
# 0  Микрофон игровой (для стриминга) Fifine AmpliG...
# 1  Сумка (кейс) для хранения портативной (блютуз)...
# 2  Стойка для микрофона/Держатель для микрофона/П...

# %%
df['full_info'] = df['name'] + '. ' + df['description']

# %%
def transform_description(x):
    x = x.replace('\n', '. ')
    return x

# %%
df['full_info'] = df.full_info.astype(str).apply(transform_description)

# %%
df.full_info
# Out:
# 0       Микрофон игровой (для стриминга) Fifine AmpliG...
# 1       Сумка (кейс) для хранения портативной (блютуз)...
# 2       Стойка для микрофона/Держатель для микрофона/П...
# 3       Микрофон петличный OutinLight петличный беспро...
# 4       Системный блок Haff Gaming Middle New Balance ...
#                               ...
# 3467    Амбушюры из искусственной кожи пенопластовые н...
# 3468    Антенна для рации автомобильная  OPTIM SUPER 9...
# 3469    Кронштейн Holder LSS-6001 черный для акустичес...
# 3470    Антенна Baofeng магнитная авто 14,5 см. Тип : ...
# 3471    Антенна для рации Diamond SRH805S sma-f. Тип :...
# Name: full_info, Length: 3472, dtype: object

# %%
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.58M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/556 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/539M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/452 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]

# %%
embeddings = model.encode(df.full_info, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/109 [00:00<?, ?it/s]

# %%
umap_embeddings = umap.UMAP(n_neighbors=15, 
                            n_components=5, 
                            metric='cosine').fit_transform(embeddings)

# %% [markdown]
# #### HDBSCAN clustering

# %%
cluster = hdbscan.HDBSCAN(min_cluster_size=2,
                          metric='euclidean',                      
                          cluster_selection_method='eom').fit(umap_embeddings)

# %%
# Prepare data
umap_data = umap.UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = cluster.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()

# %%
pd.set_option('display.max_rows', None)

# %%
len(outliers)
# Out:
# 540

# %%
clustered.groupby('labels').count()
# Out:
#          x   y
# labels
# 0       28  28
# 1       78  78
# 2       19  19
# 3        2   2
# 4        3   3
# 5        3   3
# 6        3   3
# 7       11  11
# 8        5   5
# 9       19  19
# 10       5   5
# 11      13  13
# 12       5   5
# 13       3   3
# 14       6   6
# 15       9   9
# 16       4   4
# 17      15  15
# 18       4   4
# 19      13  13
# 20       4   4
# 21       9   9
# 22       3   3
# 23       9   9
# 24       3   3
# 25       8   8
# 26       4   4
# 27       3   3
# 28       6   6
# 29       3   3
# 30       4   4
# 31       2   2
# 32       5   5
# 33      10  10
# 34       4   4
# 35      13  13
# 36       3   3
# 37      11  11
# 38       5   5
# 39       7   7
# 40       4   4
# 41      10  10
# 42      23  23
# 43       5   5
# 44       7   7
# 45       3   3
# 46       5   5
# 47       4   4
# 48       2   2
# 49       9   9
# 50       4   4
# 51       2   2
# 52       7   7
# 53       5   5
# 54       9   9
# 55       3   3
# 56       7   7
# 57       4   4
# 58       4   4
# 59       4   4
# 60       3   3
# 61       2   2
# 62       3   3
# 63       9   9
# 64       2   2
# 65       2   2
# 66      15  15
# 67       4   4
# 68       7   7
# 69       3   3
# 70      13  13
# 71       2   2
# 72       5   5
# 73       3   3
# 74      22  22
# 75      21  21
# 76       3   3
# 77       7   7
# 78       4   4
# 79       3   3
# 80       3   3
# 81       3   3
# 82       9   9
# 83       3   3
# 84       3   3
# 85       4   4
# 86       7   7
# 87       4   4
# 88       7   7
# 89       3   3
# 90       5   5
# 91       8   8
# 92       3   3
# 93       3   3
# 94       3   3
# 95      11  11
# 96       5   5
# 97       3   3
# 98       5   5
# 99       4   4
# 100      5   5
# 101      2   2
# 102      4   4
# 103      5   5
# 104      5   5
# 105      3   3
# 106      5   5
# 107      3   3
# 108     13  13
# 109      3   3
# 110      3   3
# 111      6   6
# 112      8   8
# 113      4   4
# 114      3   3
# 115      2   2
# 116      7   7
# 117      3   3
# 118      6   6
# 119      4   4
# 120      4   4
# 121      4   4
# 122      4   4
# 123      3   3
# 124      3   3
# 125      4   4
# 126      3   3
# 127      9   9
# 128      5   5
# 129      4   4
# 130      4   4
# 131     12  12
# 132      3   3
# 133      3   3
# 134      8   8
# 135      8   8
# 136      7   7
# 137      3   3
# 138      3   3
# 139      6   6
# 140      3   3
# 141     15  15
# 142      4   4
# 143      4   4
# 144      4   4
# 145      5   5
# 146      3   3
# 147      3   3
# 148      3   3
# 149      5   5
# 150      3   3
# 151      4   4
# 152      9   9
# 153     11  11
# 154      3   3
# 155      5   5
# 156      4   4
# 157      3   3
# 158     10  10
# 159      6   6
# 160      5   5
# 161      7   7
# 162      3   3
# 163      4   4
# 164      3   3
# 165     10  10
# 166      2   2
# 167      4   4
# 168      2   2
# 169      6   6
# 170      6   6
# 171      5   5
# 172      9   9
# 173      3   3
# 174      2   2
# 175      3   3
# 176      3   3
# 177      4   4
# 178     13  13
# 179      3   3
# 180      4   4
# 181      4   4
# 182      2   2
# 183     13  13
# 184      7   7
# 185      3   3
# 186      3   3
# 187      5   5
# 188     12  12
# 189      3   3
# 190      4   4
# 191      4   4
# 192      5   5
# 193      4   4
# 194      6   6
# 195      5   5
# 196      2   2
# 197      6   6
# 198     10  10
# 199      4   4
# 200      6   6
# 201      2   2
# 202      7   7
# 203      3   3
# 204      7   7
# 205      4   4
# 206      4   4
# 207      4   4
# 208      2   2
# 209      6   6
# 210      4   4
# 211      9   9
# 212      6   6
# 213      4   4
# 214      8   8
# 215      9   9
# 216      3   3
# 217      2   2
# 218      2   2
# 219     13  13
# 220      9   9
# 221      6   6
# 222     11  11
# 223      2   2
# 224      4   4
# 225      3   3
# 226      3   3
# 227      6   6
# 228      4   4
# 229     15  15
# 230      9   9
# 231      3   3
# 232      4   4
# 233      3   3
# 234      9   9
# 235      5   5
# 236     10  10
# 237      3   3
# 238      3   3
# 239      6   6
# 240      4   4
# 241      3   3
# 242      7   7
# 243      4   4
# 244      5   5
# 245      3   3
# 246      5   5
# 247      2   2
# 248      6   6
# 249      3   3
# 250      4   4
# 251      4   4
# 252      6   6
# 253      3   3
# 254      6   6
# 255      5   5
# 256      5   5
# 257      5   5
# 258      4   4
# 259      3   3
# 260     10  10
# 261      4   4
# 262      2   2
# 263      3   3
# 264      9   9
# 265      2   2
# 266     12  12
# 267      3   3
# 268      3   3
# 269      3   3
# 270     13  13
# 271      5   5
# 272      3   3
# 273      9   9
# 274      9   9
# 275      5   5
# 276      7   7
# 277      4   4
# 278      3   3
# 279      6   6
# 280      4   4
# 281      5   5
# 282      3   3
# 283      4   4
# 284      3   3
# 285      4   4
# 286      8   8
# 287     26  26
# 288      2   2
# 289      2   2
# 290      3   3
# 291      4   4
# 292      2   2
# 293      5   5
# 294      7   7
# 295     12  12
# 296      4   4
# 297      3   3
# 298      8   8
# 299     14  14
# 300      5   5
# 301      4   4
# 302      8   8
# 303      4   4
# 304      5   5
# 305      6   6
# 306      3   3
# 307      4   4
# 308      3   3
# 309     14  14
# 310      5   5
# 311      8   8
# 312      3   3
# 313     14  14
# 314      4   4
# 315      6   6
# 316      5   5
# 317      5   5
# 318      4   4
# 319      9   9
# 320      6   6
# 321      5   5
# 322      4   4
# 323      3   3
# 324      3   3
# 325      6   6
# 326      4   4
# 327     12  12
# 328      3   3
# 329      7   7
# 330      3   3
# 331      3   3
# 332      4   4
# 333      3   3
# 334      5   5
# 335      5   5
# 336      9   9
# 337      3   3
# 338      5   5
# 339      4   4
# 340      3   3
# 341      6   6
# 342      3   3
# 343      3   3
# 344      3   3
# 345     10  10
# 346      4   4
# 347      3   3
# 348     11  11
# 349      2   2
# 350      4   4
# 351      3   3
# 352      4   4
# 353      5   5
# 354      3   3
# 355      2   2
# 356      4   4
# 357      2   2
# 358      4   4
# 359     19  19
# 360      3   3
# 361      5   5
# 362      3   3
# 363      5   5
# 364      6   6
# 365      3   3
# 366      4   4
# 367      5   5
# 368      2   2
# 369      3   3
# 370      3   3
# 371     11  11
# 372      6   6
# 373      4   4
# 374     11  11
# 375      9   9
# 376      3   3
# 377      5   5
# 378      4   4
# 379      6   6
# 380      9   9
# 381     10  10
# 382      6   6
# 383      9   9
# 384     12  12
# 385      5   5
# 386      5   5
# 387      3   3
# 388      4   4
# 389      2   2
# 390      3   3
# 391      6   6
# 392      6   6
# 393     14  14
# 394      5   5
# 395     17  17
# 396     11  11
# 397      6   6
# 398     11  11
# 399      5   5
# 400     13  13
# 401      6   6
# 402      6   6
# 403      5   5
# 404      6   6
# 405      6   6
# 406     12  12
# 407      3   3
# 408     12  12
# 409      5   5
# 410      4   4
# 411      6   6
# 412      6   6
# 413      3   3
# 414      9   9
# 415      2   2
# 416      5   5
# 417      6   6
# 418      5   5
# 419     11  11
# 420      3   3
# 421      7   7
# 422      4   4
# 423     19  19
# 424      4   4
# 425      9   9
# 426      3   3
# 427      5   5
# 428      4   4
# 429      6   6
# 430      6   6
# 431     13  13
# 432     14  14
# 433     13  13
# 434      6   6
# 435      6   6
# 436     10  10
# 437      3   3
# 438      3   3
# 439      6   6
# 440      3   3
# 441      7   7
# 442      5   5
# 443      4   4
# 444      4   4
# 445      3   3
# 446      3   3
# 447      7   7
# 448      3   3
# 449      8   8
# 450      3   3
# 451      4   4
# 452      9   9
# 453      4   4
# 454     13  13
# 455      6   6
# 456      5   5
# 457      4   4
# 458      6   6
# 459      6   6
# 460      5   5
# 461      3   3
# 462      6   6
# 463      2   2
# 464     11  11
# 465      9   9
# 466      5   5
# 467     15  15
# 468      8   8
# 469      5   5
# 470      3   3
# 471      4   4
# 472      3   3
# 473      8   8
# 474      2   2
# 475      5   5
# 476      5   5
# 477      6   6
# 478      2   2
# 479      5   5
# 480      3   3
# 481      7   7
# 482      3   3
# 483      6   6
# 484      5   5
# 485      3   3
# 486      9   9
# 487      6   6
# 488     19  19
# 489      4   4
# 490      3   3
# 491      3   3
# 492     10  10
# 493      3   3
# 494      6   6
# 495     10  10
# 496      5   5
# 497      3   3

# %%
result_df = pd.merge(df, result, left_index=True, right_index=True)

# %%
result_df[result_df.labels==108]
# Out:
#       product_no    brand category  \
# 50            50  Sturman  Окуляры
# 114          110  Sturman  Окуляры
# 211          207  Sturman  Окуляры
# 272          267  Sturman  Окуляры
# 342          338  Sturman  Окуляры
# 354          349  Sturman  Окуляры
# 418          417  Sturman  Окуляры
# 431          428  Sturman  Окуляры
# 1279        1280  Sturman  Окуляры
# 1280        1281  Sturman  Окуляры
# 1348        1349  Sturman  Окуляры
# 1559        1559  Sturman  Окуляры
# 1560        1560  Sturman  Окуляры
#
#                                                    link  price  \
# 50    https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 114   https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 211   https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 272   https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 342   https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 354   https://www.ozon.ru/product/okulyar-teleskopa-...   1527
# 418   https://www.ozon.ru/product/okulyar-teleskopa-...   2414
# 431   https://www.ozon.ru/product/okulyar-teleskopa-...   1527
# 1279  https://www.ozon.ru/product/okulyar-teleskopa-...   1527
# 1280  https://www.ozon.ru/product/okulyar-teleskopa-...   1527
# 1348  https://www.ozon.ru/product/okulyar-teleskopa-...   1938
# 1559  https://www.ozon.ru/product/okulyar-teleskopa-...   1527
# 1560  https://www.ozon.ru/product/okulyar-teleskopa-...   1527
#
#                                    description  seller_id  \
# 50    Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 114   Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 211   Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 272   Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 342   Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 354   Тип : Окуляр\nГарантийный срок : 1 год\n     433770
# 418   Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 431   Тип : Окуляр\nГарантийный срок : 1 год\n     433770
# 1279  Тип : Окуляр\nГарантийный срок : 1 год\n      15336
# 1280  Тип : Окуляр\nГарантийный срок : 1 год\n      93489
# 1348  Тип : Окуляр\nГарантийный срок : 1 год\n     261175
# 1559  Тип : Окуляр\nГарантийный срок : 1 год\n      15336
# 1560  Тип : Окуляр\nГарантийный срок : 1 год\n      93489
#
#                                    name  \
# 50     Окуляр телескопа К20мм /Ф31,75мм
# 114    Окуляр телескопа К20мм /Ф31,75мм
# 211    Окуляр телескопа К20мм /Ф31,75мм
# 272    Окуляр телескопа К20мм /Ф31,75мм
# 342    Окуляр телескопа К20мм /Ф31,75мм
# 354   Окуляр телескопа PL25мм /Ф31,75мм
# 418    Окуляр телескопа К20мм /Ф31,75мм
# 431   Окуляр телескопа PL25мм /Ф31,75мм
# 1279  Окуляр телескопа PL25мм /Ф31,75мм
# 1280  Окуляр телескопа PL25мм /Ф31,75мм
# 1348  Окуляр телескопа PL25мм /Ф31,75мм
# 1559  Окуляр телескопа PL25мм /Ф31,75мм
# 1560  Окуляр телескопа PL25мм /Ф31,75мм
#
#                                              image_link  \
# 50    https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 114   https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 211   https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 272   https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 342   https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 354   https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 418   https://cdn1.ozone.ru/s3/multimedia-p/63007902...
# 431   https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 1279  https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 1280  https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 1348  https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 1559  https://cdn1.ozone.ru/s3/multimedia-o/63007902...
# 1560  https://cdn1.ozone.ru/s3/multimedia-o/63007902...
#
#                                               full_info          x         y  \
# 50    Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748383 -1.214943
# 114   Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748445 -1.215032
# 211   Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748459 -1.215036
# 272   Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748496 -1.215017
# 342   Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748509 -1.215067
# 354   Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748526 -1.215082
# 418   Окуляр телескопа К20мм /Ф31,75мм. Тип : Окуляр... -14.748528 -1.215133
# 431   Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748446 -1.215007
# 1279  Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748494 -1.215025
# 1280  Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748449 -1.214992
# 1348  Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748429 -1.214971
# 1559  Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748389 -1.214935
# 1560  Окуляр телескопа PL25мм /Ф31,75мм. Тип : Окуля... -14.748371 -1.214919
#
#       labels
# 50       108
# 114      108
# 211      108
# 272      108
# 342      108
# 354      108
# 418      108
# 431      108
# 1279     108
# 1280     108
# 1348     108
# 1559     108
# 1560     108

# %%
silhouette_score = metrics.silhouette_score(umap_embeddings, cluster.labels_, metric='euclidean')
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.48077583

# %% [markdown]
# #### OPTICS algorithm

# %%
clustering_optics = OPTICS(min_samples=2).fit(umap_embeddings)

# %%
silhouette_score = metrics.silhouette_score(umap_embeddings, clustering_optics.labels_, metric='euclidean')
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Silhouette_score:
# 0.33922002

# %%
# Prepare data
umap_data = umap.UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
result = pd.DataFrame(umap_data, columns=['x', 'y'])
result['labels'] = clustering_optics.labels_

# Visualize clusters
fig, ax = plt.subplots(figsize=(20, 10))
outliers = result.loc[result.labels == -1, :]
clustered = result.loc[result.labels != -1, :]
plt.scatter(outliers.x, outliers.y, color='#BDBDBD', s=0.05)
plt.scatter(clustered.x, clustered.y, c=clustered.labels, s=0.05, cmap='hsv_r')
plt.colorbar()
